# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !source ../tokens.sh
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../src/')) # or the path to your source code
sys.path.insert(0, module_path)

# %%
# This won't work directly, so instead manually set them:
with open('../tokens.sh') as f:
    for line in f:
        if line.startswith('export'):
            key, value = line.strip().split(' ')[1].split('=')
            os.environ[key] = value

# Now you can access the token
if not (os.environ.get('HF_TOKEN') and os.environ.get('OPENROUTER_API_KEY')):
    raise ValueError("Environment variables HF_TOKEN and OPENROUTER_API_KEY must be set.")

# %%
from app import interactive_smart_assistant
interactive_smart_assistant()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Extracted text from ./uploads/lettre-de-procuration-dadie_2.pdf:
#
#
#
#
#
#
#
#
#
#  Fait à Anières-Sur-Seine, Le 17/06/2025
# Je soussigné M. DADIE Koutoua Christ né(e) le 09/07/2001 donne par la présente procuration à M. Emmanuel
# KONAN pour la réalisation des tâches suivantes en mon nom pour le logement N°116 de la résidence les Aiglons
# située au 145 Bd. National 92500, Rueil Malmaison.
# ☒  Réalisation et signature de l'état des lieux (entrée et sortie)
# ☒  Signature de mon contrat de location
# Cette procuration est valable du 17/06/2025 au 18/06/2025.
# Pour faire valoir ce que de droit.
# Bon pour mandat                                                                 Bon pour acceptation
# Signature :                                                         Signature du bénéficiaire de la procuration :
# Pensez à présenter la carte d'identité du mandant et du mandataire
#
#
#
# User question:  what is a PKI ?
# additional information :  {'file': 'content', './uploads/lettre-de-procuration-dadie_2.pdf': "                                                                                              \n \n \n \n \n \n \n \n \n \n Fait à Anières-Sur-Seine, Le 17/06/2025 \nJe soussigné M. DADIE Koutoua Christ né(e) le 09/07/2001 donne par la présente procuration à M. Emmanuel \nKONAN pour la réalisation des tâches suivantes en mon nom pour le logement N°116 de la résidence les Aiglons \nsituée au 145 Bd. National 92500, Rueil Malmaison. \n☒  Réalisation et signature de l'état des lieux (entrée et sortie) \n☒  Signature de mon contrat de location \nCette procuration est valable du 17/06/2025 au 18/06/2025. \nPour faire valoir ce que de droit. \nBon pour mandat                                                                 Bon pour acceptation \nSignature :                                                         Signature du bénéficiaire de la procuration :  \nPensez à présenter la carte d'identité du mandant et du mandataire  \n \n  \n"}
# User question:  what is an HSM ?
# additional information :  {'file': 'content', './uploads/lettre-de-procuration-dadie_2.pdf': "                                                                                              \n \n \n \n \n \n \n \n \n \n Fait à Anières-Sur-Seine, Le 17/06/2025 \nJe soussigné M. DADIE Koutoua Christ né(e) le 09/07/2001 donne par la présente procuration à M. Emmanuel \nKONAN pour la réalisation des tâches suivantes en mon nom pour le logement N°116 de la résidence les Aiglons \nsituée au 145 Bd. National 92500, Rueil Malmaison. \n☒  Réalisation et signature de l'état des lieux (entrée et sortie) \n☒  Signature de mon contrat de location \nCette procuration est valable du 17/06/2025 au 18/06/2025. \nPour faire valoir ce que de droit. \nBon pour mandat                                                                 Bon pour acceptation \nSignature :                                                         Signature du bénéficiaire de la procuration :  \nPensez à présenter la carte d'identité du mandant et du mandataire  \n \n  \n"}
# Extracted text from ./uploads/150ce100-f227-42ed-bd08-f3d69e87234c.pdf: Ornisec Academy
# Connaissances Systèmes et réseaux
#
# Introduction
#
# Introduction
# Cette formation consiste à introduire les notions techniques de
# base
# permettant
# à
# un
# consultant/auditeur
# de
# mieux
# comprendre les mesures de sécurité appliquées dans les
# différents types d’environnement.
# Elle couvre à la fois les périmètres Système et Réseau.
#
# Processus d’une entreprise
#
# Processus d’une entreprise
# Afin de mieux comprendre les différents risques métiers d’une entreprise, il faut tout d’abord comprendre le
# fonctionnement général d’une entreprise, à savoir les processus et leur organisation.
# Ce chapitre permet de présenter les processus classiques d’une organisation ainsi que le rôle de chaque
# processus. On les retrouve notamment lors des analyses des risques (valeur métier => Mission)
# Chaque entreprise, réalise des missions. Une mission est pilotée par un service/département et consiste à réaliser
# un certain nombre de processus (activité périodique ayant des inputs et produisant des outputs)
#
# Traitement,
# Transformation,
# Valeur ajoutée
# Processus
# Input
# Output
# L’approche par les processus permet d’améliorer l’efficacité
# de l’organisation.
# Le management par les processus est un levier de la
# performance de l’organisation
# Cadrer par le norme ISO 9000 (Processus
# Qualité)
# Approche par processus
#
# Types de processus en entreprise
# Pour peu classer les métiers d’une entreprise en 3 catégories de processus :
# •
# Processus de management : L’ensemble des activités pilotées par la DG afin de gérer et piloter la société
# ✓Définition des stratégies pluriannuelles
# ✓Programme de transformation
# ✓Programme de croissance (fusion & acquisition)
# ✓Gestion de la performance de l’activité
# ✓…..
# •
# Processus opérationnel (Production) : Ce sont les activités de base d’une entreprise, le cœur de métier et les
# missions principales (raisons d’être d’une entreprise)
# ✓R&D
# ✓Fabrication de produit
# ✓Transport de passager
# ✓Inspection et filtrage de marchandise
# ✓…..
# •
# Processus support : Tout ce qui permet la réalisation des processus opérationnels
# ✓Gestion RH
# ✓Gestion financière
# ✓IT
# ✓….
#
# MANAGEMENT
# PROCESSES
# OPERATING
# PROCESSES
# SUPPORT
# PROCESSES
# OFFERS, SOLUTIONS & TECHNOLOGIES MANAGEMENT
# GLOBAL ENGINEERING & DELIVERY MANAGEMENT
# OPERATIONS & CAPACITY MANAGEMENT
# R&D
# FINANCE
# PURCHASING
# Sales
# HR
# IT
# LEGAL
# INTERNAL AUDIT,
# RISKS &
# INTERNAL
# CONTROL
# MANAGEMENT
# KM
# STRATEGY
# & MARKETING
# GENERAL
# MANAGEMENT
# TRANSFORMATION
# COMMUNICATION
# Types de processus en entreprise
# Ci-dessous un exemple de processus de la société ALTRAN, cabinet de conseil en IT
#
# MANAGEMENT
# PROCESSES
# OPERATING
# PROCESSES
# SUPPORT
# PROCESSES
# Processus de Direction
# Ils sont placés sous la responsabilité du dirigeant qui fixe les objectifs et déploie les ressources
# nécessaires. (Stratégie Global, analyse des résultats, amélioration continu)
# Met en place un Système de Management : détermination d’une politique pour l’organisation et
# du pilotage des actions mises en œuvre pour atteindre ses objectifs
# Processus de réalisation
# Couvre le cycle de vie d’un produit ou Service
# Détecter le besoin-client → concevoir le produit → mettre au point → fabriquer → vendre (avec
# prise en compte des normes, des démarches de sécurité…),
# → Ils permettent la réalisation du produit ou du service fourni par l’entreprise à ses clients et
# correspondent ainsi à l’activité « métier » de l’organisation.
# Processus de soutien
# Fournir les services et ressources nécessaires au bon fonctionnement des processus métier:
# -
# Ils permettent l’allocation des ressources (matérielles et immatérielles) utiles pour produire
# dans les meilleures conditions,
# -
# Ils représentent une activité interne, généralement transversale, permettant d’assurer le bon
# fonctionnement de l’entreprise
# Types de processus en entreprise
#
# •Planification de la réalisation du produit
# •Processus relatifs aux clients
# •
# Détermination et revue des exigences
# produit
# •
# Communication avec le client
# •Conception et développement
# •
# Planification de la conception et du
# développement
# •
# Éléments d’entrée, Éléments de sortie
# et Revue
# •
# Vérification et Validation
# •
# Maîtrise des modifications
# •Production et préparation du service
# •
# Maîtrise de la production et de la
# préparation du service
# •
# Validation des processus de production
# et de préparation du service
# •
# Identification et traçabilité
# •
# Propriété du client
# •
# Préservation du produit
# •Maîtrise des dispositifs de surveillance
# •Mise à disposition des
# ressources (en particulier
# financière)
# •Ressources humaines
# •Compétences, sensibilisation
# et formation
# •Infrastructures
# •Environnement de travail
# •Achats
# •
# Processus d’achat
# •
# Informations relatives
# aux achats
# •
# Vérification du produit
# acheté
# Processus de réalisation
# Processus de direction
# Processus Support
# •Engagement de la direction
# •Ecoute client
# •Politique qualité
# •Planification
# •Responsabilité, autorité et
# communication
# •Revue de direction
# •Surveillance et mesures
#
# Satisfaction du client
#
#
# Audit interne
#
# Surveillance et mesure
# Maîtrise du produit
#
# Analyse des données
# •Amélioration
#
# Amélioration continue
#
# Action corrective
#
# Action préventive
# Types de processus en entreprise
#
# Active Directory
#
# Présentation
# C’est un annuaire utilisé pour gérer les ressources d’une organisation (Domaine, Utilisateur et machine).
# Il permet de gérer les informations des ressources, les politiques, l’authentification et l’autorisation.
# Un annuaire est composé d’une forêt (Organisation). Une forêt est composée d’un ou de plusieurs arbre
# (domaine). Un arbre est composé de plusieurs Branche (OU).
# Une branche peut avoir d’autre branche (OU) ou des feuilles (Machine, groupe  et Utilisateur)
# Une organisation est composée de plusieurs
# domaines
# Forêt composée de plusieurs arbres
# Un domaine est composé de
# plusieurs unités organisationnelles
# (OU)
# Un arbre dispose de plusieurs
# branches
# Un compte administrateur de domaine, est administrateur de chaque machine, utilisateur
#
# Classes et attributs
# Au sein de l’annuaire Active Directory, il y a différents types d’objets, comme par exemple
# les utilisateurs, les ordinateurs, les serveurs, les unités d’organisation ou encore les
# groupes. En fait, ces objets correspondent à des classes, c’est-à-dire des objets
# disposant des mêmes attributs.
# De ce fait, un objet ordinateur sera une instance d’un objet de la classe « Ordinateur »
# avec des valeurs spécifiques à l’objet concerné.
# Certains objets peuvent être des containers d’autres objets, ainsi, les groupes
# permettront de contenir plusieurs objets de types utilisateurs afin de les regrouper et de
# simplifier l’administration. Par ailleurs, les unités d’organisation sont des containers
# d’objets afin de faciliter l’organisation de l’annuaire et permettre une organisation avec
# plusieurs niveaux.
# Sans les unités d’organisations, l’annuaire ne pourrait pas être trié correctement et
# l’administration serait moins efficace. Comparez les unités d’organisations à des
# dossiers qui permettent de ranger les objets à l’intérieur, si cela est plus compréhensible
# pour vous.
#
# Le schéma
# Par défaut, tout annuaire Active Directory dispose de classes prédéfinies ayant chacune une liste
# d’attributs bien spécifique, et propre à tout annuaire, cela est défini grâce à un schéma.
# Le schéma contient la définition de toutes les classes et de tous les attributs disponibles et
# autorisés au sein de votre annuaire. Il est à noter que le schéma est évolutif, le modèle de base
# n’est pas figé et peut évoluer selon vos besoins, voir même pour répondre aux prérequis de
# certaines applications.
# Par exemple, l’application de messagerie Microsoft Exchange effectue des modifications au
# schéma lors de son installation.
# Les modifications du schéma doivent être réalisées avec précaution, car l’impact est important et
# se ressentira sur toute la classe d’objets concernée. Pour preuve, le schéma est protégé et les
# modifications contrôlées, puisque seuls les membres du groupe « Administrateurs du schéma »
# peuvent, par défaut, effectuer des modifications.
#
# Le schéma
# Console pour gérer le schéma de l'annuaire Active Directory
# Console pour gérer le schéma de
# l'annuaire Active Directory
#
# Les partitions d’annuaire
# La base de données Active Directory est divisée de façon logique en trois partitions de répertoire
# (appelé « Naming Context »). Ces trois partitions sont la partition de schéma, la partition de
# configuration, et la partition de domaine.
# • La partition de schéma : cette partition contient l'ensemble des
# définitions des classes et attributs d’objets, qu’il est possible de créer au
# sein de l'annuaire Active Directory. Cette partition est unique au sein d’une
# forêt.
# • La partition de configuration : cette partition contient la topologie de la
# forêt (informations sur les domaines, les liens entre les contrôleurs de
# domaines, les sites, etc.). Cette partition est unique au sein d’une forêt.
# • La partition de domaine : cette partition contient les informations de
# tous les objets d'un domaine (ordinateur, groupe, utilisateur, etc.). Cette
# partition est unique au sein d’un domaine, il y aura donc autant de
# partitions de domaine qu’il y a de domaines.
#
# Qu’est-ce qu’un contrôleur de domaine ?
# Lorsque l’on crée un domaine, le serveur depuis lequel on effectue cette création est promu au
# rôle de « contrôleur de domaine » du domaine créé. Il devient contrôleur du domaine créé, ce qui
# implique qu’il sera au cœur des requêtes à destination de ce domaine. De ce fait, il devra vérifier
# les identifications des objets, traiter les demandes d’authentification, veiller à l’application des
# stratégies de groupe ou encore stocker une copie de l’annuaire Active Directory.
# Un contrôleur de domaine est indispensable au bon fonctionnement du domaine, si l’on éteint le
# contrôleur de domaine ou qu’il est corrompu, le domaine devient inutilisable.
# De plus, lorsque vous créez le premier contrôleur de domaine dans votre organisation, vous
# créez également le premier domaine, la première forêt, ainsi que le premier site. Nous
# aborderons la notion de forêt et de site dans un autre chapitre. Gardez à l’esprit qu’un contrôleur
# de domaine est un serveur qui contient une copie de l’annuaire Active Directory.
#
# Le fichier de BDD NTDS.dit et la réplication des contrôleurs de
# domaine
# Sur chaque contrôleur de domaine, on trouve une copie de la base de données de l’annuaire Active
# Directory. Cette copie est symbolisée par un fichier « NTDS.dit » qui contient l’ensemble des données
# de l’annuaire.
# À noter qu’il est possible de réaliser des captures instantanées de ce fichier afin de le consulter en
# mode « hors ligne » avec des outils spécifiques.
# De nos jours, il est inévitable d’avoir au minimum deux contrôleurs de domaine pour assurer la
# disponibilité et la continuité de service des services d’annuaire. De plus, cela permet d’assurer la
# pérennité de la base d’annuaire qui est très précieuse. À partir du moment où une entreprise crée
# un domaine, même si ce domaine est unique, il est important de mettre en place au minimum
# deux contrôleurs de domaine.
# Sur les anciennes versions de Windows Server, notamment Windows Server 2000 et Windows
# Server 2003, le mécanisme FRS (File Replication Service) était utilisé pour la réplication. Depuis
# Windows Server 2008, FRS est mis de côté pour laisser la place à DFSR (Distributed File System
# Replication), qui est plus fiable et plus performant.
# Ainsi, les contrôleurs de domaine répliquent les informations entre eux à intervalle régulier, afin de
# disposer d’un annuaire Active Directory identique. Sans rentrer dans les détails, un numéro de
# version est géré par les contrôleurs de domaine, ce qui permet à un contrôleur de domaine de
# savoir s’il est à jour ou non par rapport à la version la plus récente de l’annuaire.
#
# Le fichier de BDD NTDS.dit et la réplication des contrôleurs de
# domaine
# Sur le schéma ci-dessous, on trouve deux contrôleurs de domaine, présent au sein d’un même
# domaine et qui réplique entre eux des informations. Des postes de travail client sont également
# présents et intégrés dans ce domaine, ils contactent les contrôleurs de domaine pour effectuer
# différentes actions (authentification d’un utilisateur, demande d’accès à une ressource...).
# Comme on peut le voir sur le schéma ci-dessous, lorsqu’il y a plusieurs contrôleurs de domaine,
# les requêtes sont réparties.
# cours-active-directory-3
#
# Symbolisation d’un  domaine
# Lorsque vous verrez des schémas d’architecture Active Directory, vous verrez les domaines
# représentés par des triangles. Ainsi, notre domaine « it-connect.local » pourrait être schématisé
# ainsi :
# cours-active-directory-5
# Au sein du domaine schématisé ci-dessous, on retrouvera tout un ensemble
# d’Unités d’Organisation remplies d’objets de différentes classes : utilisateurs,
# ordinateurs, groupes, contrôleurs de domaine, etc.
#
# Symbolisation d’un  domaine
# Vous n’êtes pas sans savoir que de nombreuses entreprises ont plusieurs succursales, ce qui
# implique plusieurs sites sur différents emplacements géographiques. Selon l’importance de ces
# sites, on pourra envisager de créer un sous-domaine au domaine principal, voir même plusieurs
# sous-domaines selon le nombre de succursales. Voyons un exemple.
# On part du domaine de base « it-connect.local », auquel on ajoute deux sous-domaines :
# « paris.it-connect.local » et «londres.it-connect.local » puisque nous avons deux succursales, une
# à Paris, l’autre à Londres. Voici la représentation de cette arborescence :
# cours-active-directory-6
#
# La notion d’arbre
# La notion d’arbre doit vous faire penser à un ensemble avec différentes branches, si c’est le cas,
# vous êtes sur la bonne voie. En effet, lorsqu’un domaine principal contient plusieurs sous-
# domaines on parle alors d’arbre, où chaque sous-domaine au domaine racine représente une
# branche de l’arbre.
# Un arbre est un regroupement hiérarchique de plusieurs domaines.
# Par exemple, la schématisation des domaines utilisés précédemment représente un arbre :
# cours-active-directory-7
# Les domaines d’un même
# arbre partagent un
# espace de nom contigu
# et hiérarchique, comme
# c’est le cas avec
# l’exemple du domaine
# « it-connect.local ».
#
# La notion d’arbre
# Ainsi l'ensemble de l'AD peut être visualisé comme un arbre, avec des branches qui se ramifient. Les branches
# représentent les unités organisationnelles (OU) qui sont utilisées pour organiser les objets de manière logique.
# Sous-répertoires (OU) : Les unités organisationnelles sont comme des sous-répertoires dans un arbre de
# dossiers. Elles permettent de regrouper des objets (utilisateurs, machines, groupes) selon une logique
# organisationnelle propre à l'entreprise.
# Feuilles de la branche : Les objets (utilisateurs, machines, groupes) sont les feuilles de chaque branche. Ils
# sont les entités individuelles gérées dans l'AD.
# Informations (Attributs) : Chaque objet (fichier) dans Active Directory possède des attributs qui définissent
# ses caractéristiques et ses propriétés. Par exemple, pour un utilisateur, les attributs peuvent inclure le nom, le
# mot de passe, le département, etc.
#
# La notion de forêt
# Si vous êtes d’accord avec moi pour dire qu’une forêt c’est un ensemble d’arbres, alors vous avez
# déjà compris le principe de la notion de « forêt » dans un environnement Active Directory.
# En effet, une forêt est un regroupement d’une ou plusieurs arborescences de domaine, autrement
# dit d’un ou plusieurs arbres. Ces arborescences de domaine sont indépendantes et distinctes bien
# qu’elles soient dans la même forêt.
# L’exemple que nous utilisons jusqu’à maintenant
# avec le domaine principal et les deux sous domaines
# représente une forêt. Seulement, cette forêt ne
# contient qu’un seul arbre.
# Imaginons maintenant que nous rachetons la
# société « Learn-Online » et que nous décidons de
# créer un domaine racine « learn-online.local », ainsi
# que trois sous-domaines pour les deux succursales
# situées à Paris et Rennes, et un troisième sous-
# domaine pour un environnement de développement
# situé à Rennes. On obtiendra : paris.learn-
# online.local, rennes.learn-online.local et
# dev.rennes.learn-online.local. On obtiendra un
# arbre avec la racine « learn-online.local ».
# cours-active-directory-8
#
# La notion de forêt
# Pour simplifier l’administration, les accès et unifier le système d’information, on peut décider de
# créer cet arbre « Learn-Online » dans la même forêt que celle où se situe l’arbre « IT-Connect ».
# On peut alors affirmer que les différentes arborescences d’une forêt ne partagent pas le même
# espace de nom et la même structure.
# Ainsi, on obtiendra une jolie forêt :
# cours-active-directory-9
#
# Le niveau fonctionnel
# À la création d’un domaine, un niveau fonctionnel est défini et il correspond généralement à la
# version du système d’exploitation depuis lequel on crée le domaine. Par exemple, si l’on effectue la
# création du domaine depuis un serveur sous Windows Server 2012, le niveau fonctionnel sera
# « Windows Server 2012 ».
# Dans un environnement existant, on est souvent amené à faire évoluer notre infrastructure,
# notamment les systèmes d’exploitation, ce qui implique le déclenchement d’un processus de
# migration. Une étape incontournable lors de la migration d’un Active Directory vers une version
# plus récente et le changement du niveau fonctionnel. Ainsi, il est important de savoir à quoi il
# correspond et les conséquences de l’augmentation du niveau.
# Pourquoi augmenter le niveau fonctionnel ?
# Plus le niveau fonctionnel est haut, plus vous pourrez bénéficier des dernières nouveautés
# liées à l’Active Directory et à sa structure. Ce qui rejoint la réponse à la question
# précédente.
# Par ailleurs, vous serez obligé d’augmenter le niveau fonctionnel pour ajouter la prise en
# charge des derniers systèmes d’exploitation Windows pour les contrôleurs de domaine. Par
# exemple, si le niveau fonctionnel est « Windows Server 2003 », vous ne pourrez pas
# ajouter un nouveau contrôleur de domaine sous Windows Server 2012 et les versions plus
# récentes.
#
# Installation
# L’AD est un rôle dans un serveur Windows. Pour l’installer, il suffit d’activer le rôle AD DS (Domain Service) sur le
# serveur.
# Lorsqu’on installe le rôle AD DS, il installe automatiquement le rôle DNS ainsi que les outils d’administrateur
# (RSAT: Remote Server Administration Tools).
# Une fois que l’AD est installé, il nous propose de choisir le serveur actuel en tant que contrôleur de domaine.
# C’est le serveur qui sera donc utilisé pour contrôler tout ce qui est géré par l’AD.
#
# Installation
# À la fin de l’installation, on peut remarquer que les rôles AD DS et DNS ont été ajoutés à notre serveur.
# Le rôle AD DS sert de service central pour la gestion des identités et des accès.
#
# Administration
# Une fois l’AD installé, les outils d’administration sont accessibles depuis le contrôleur de domaine (le serveur
# où l’AD est installé et qui est déclaré comme contrôleur).
# Pour gérer les ressources (utilisateurs, machines) on lance l’outil : Active Directory Users & computers
# Ornisec.com = Domaine
# Builtin = c’est une OU qui contient les groupes par défaut de l’AD
# Computers = l’OU des machines
# Domain Controllers = l’OU des DC
# Managed Service Accounts = l’OU des services managés
# Users = l’OU des utilisateurs
#
# Administration
# Organiser les OU
# OU CCI*
# Les GPO
# (Group Policy Object)
# Les sous OU
# - Groupe
# - Site
# - Etc.
# *CCI: nom d’un client d’ORNISEC
#
# Administration
# OU vs Groupe
# OU ORNISEC
# Les sous OU
# - Groupe
# - Site
# - Département
# - Etc.
# Les OU sont utilisés pour organiser les ressources
# Les OU sont différents des groupes :
# •
# Les OU sont utilisés pour faciliter la recherche d’une entrée au niveau de l’AD.
# Ça permet juste d’organiser les entrés de façon logique pour faciliter le travail
# des administrateurs
# •
# Les Groupes sont utilisés pour générer des configurations et des autorisations.
# On peut par exemple appliquer une GPO à un groupe qui contient des
# utilisateurs et des machines.
#
# Administration
# Ajouter un Poste de travail au domaine
# Pour ajouter un ordinateur au domaine, il faut le faire depuis l’ordinateur.
# Pour cela, il suffit de se connecter à l’ordinateur qu’on souhaite ajouter :
# •
# Configurer le DNS en mettant l’IP du contrôleur de domaine. Ceci est
# nécessaire pour la résolution du domaine
# •
# Changer MemberOf, en mettant le domaine à la place de Workgroup.
# •
# Il va nous demander de s’authentifier, il faut utiliser un compte admin de
# domaine
# •
# Et voilà. La machine sera ajoutée automatiquement à l’OU « Computer »
# de notre domaine
#
# Administration
# GPO
# Les GPO sont utilisé pour configurer les machines et les utilisateurs :
# -
# Appliquer des politiques de mot de passe
# -
# Appliquer des scripts à la connexion
# -
# Installer des imprimantes
# -
# Configuration la redirection de dossier pour stocker les données utilisateurs dans
# un partage
# -
# Etc.
# Pour créer des GPO, il suffit d’utiliser l’outil d’administration : Group Policy Manager
#
# Administration
# GPO – Les paramètres
# Les paramètres sont appliqués sur les machines ou les
# utilisateurs :
#
# GPO sur PC
# GPO sur user
#
# Administration
# GPO – Application d’une GPO
# Une GPO peut être appliquée à
# un des utilisateurs ou des
# groupes d’utilisateur
#
# Cette GPO est appliquée au groupe
# Utilisateur authentifié
#
# SID – Access Token -
# Impersonation
#
# SID - Définition
# Pour identifier les utilisateurs et les groupes, Windows utilise des identifiants uniques
# appelés SID : Security Identifier.
# Ce sont des identifiant unique sur lequel se base tous les mécanismes d’authentification
# et de contrôle d’accès.
# Chaque utilisateur et groupe dispose de son propre SID, ce qui permet d’avoir le même
# compte même après la modification du login utilisateur.
# Les caractéristiques des SID sont les suivants :
# •
# Unique pour les utilisateurs et les groupes et n’est jamais réutilisé dans le même système
# •
# Il est toujours associé à un Access Token
# •
# C’est le seul identifiant sur lequel se base l’ensemble des ressources et des processus pour
# identifier l’utilisateur qui demande un accès
# •
# Il ne change jamais dans le temps
#
# SID - Format
# Pour accéder à notre SID, il suffit d’exécuter la commande : whoami /all
# S-1-5-21-3435738111-381107528-3113222742-500
# <String is an SID> - <Version of SID> - <Identifying Authority> - <Domain or local identifier> - <Relative ID>
#
# SID – Format
# Relative ID
# C’est la partie variable d’un SID, c'est le dernier nombre du SID. À partir du RID, on peut deviner le type de
# compte : Utilisateur, administrateur local ou invité.
# Exemple :
#      S-1-5-21-397955417-62688126-188441444-1001
# Cette information est très pertinente pour un attaquant ayant réussi à compromettre le hash associé à un SID.
# Il va systématiquement chercher les SID ayant un RID = 500
# Les valeurs possibles pour un RID sont les suivantes :
# Compte Administrateur local : 500
# Compte invité : 501
# Compte utilisateur normal : ça commence à 1000 et c’est incrémenté de 1 pour chaque utilisateur
# RID
# SID du domaine
#
# SID - Exemple
# On peut lister le SID de tous les utilisateurs et groupes d’une machine via les clés de registre :
#
# SID filtering
# SIDHistory
# Lorsqu'un utilisateur migre d'un domaine A vers un domaine B, il hérite d'un nouveau SID dans le nouveau domaine. De ce fait, avec son nouveau compte, cet
# utilisateur perd l'accès à toutes les ressources de l'ancien domaine Active Directory ! En phase de migration/transition, ceci peut s'avérer problématique. C'est là que
# l'attribut sIDHistory intervient. En stockant dans l'attribut "sIDHistory" du nouveau compte le SID de l'utilisateur dans l'ancien domaine, il est possible de faire le lien
# entre les deux objets dans les deux domaines et de conserver l'accès aux ressources pendant la phase de migration. Ce mécanisme est pratique pour les
# utilisateurs et les groupes de sécurité.
# SID Filtering
# Est un mécanisme utilisé dans les relations d’approbation pour protéger l’accès aux ressources d’un domaine à l’autre. Plusieurs outils permettent de profiter des
# relations d’approbations pour élever ses priviléges, notamment en partant d’un domaine enfant vers un domaine parent. Ceci exploite notamment les “SIDHistory”.
# Il est également possible de s’en sortir avec mimikatz en générant un golden ticket qui inclut les SID History du groupe Enterprise Admin du domaine parent.
# Il est possible d’utiliser le mécanisme de “SID Filtering” pour limiter ce type d’attaque. Cependant, l’utilisation de ce mécanisme ne doit pas se faire au sein d’une
# même forêt, ce qui peut causer des problèmes de réplication (voir http://windowsitpro.com/windows-server/exploiting-sidhistory-ad-attribute). En gros, il vaut mieux
# mettre le domaine dans une forêt séparée si on ne lui fait pas confiance.
# It has been noted that enabling SID Filtering between trusts in an Active Directory forest would mitigate this since SID History wouldn’t work. By enabling SID filtering you
# can keep a hacker from spoofing a SID across a trust.
# Une vulnérabilité de sécurité existe avec l'utilisation de SID History,. Un administrateur dans un domaine de confiance peut modifier SID History d'un utilisateur, ce qui
# pourrait lui accorder des privilèges élevés dans le domaine de confiance.
# Pour éviter que cela ne se produise, vous pouvez activer le SID Filtering pour un domaine de confiance. Lorsque le SID Siltring est activé, les seuls SID utilisés dans le
# cadre du Ticket Kerkeros d'un utilisateur proviennent du domaine de confiance lui-même. Les SID d'autres domaines de confiance (de la même forêt) ne sont pas pris
# en compte. Le SID Filtering rend les choses plus sûres, mais empêche l'utilisation de l'historique des SID et peut causer des problèmes lors de projet de transition.
#
# Access Token
# C’est l’équivalent d’un cookie de session, il contient toutes les informations permettant de savoir quels sont les
# droits de l’utilisateur authentifié, identifié avec son SID :
# C’est ce qui détermine le contexte sécurité d’un utilisateur
# L'Access Token est créé à la suite de chaque authentification.
#
# Lorsqu’un utilisateur s’authentifie, un Access Token lui est créé et sera associé à un objet qui s’appelle : Security
# Descriptor. Cet objet est passé à n’importe quelle fonction/Service/Ressource qui nécessite une
# authentification et un contrôle d’accès. Il permet au service de vérifier que l’utilisateur dispose bien des droits
# d’accès à la ressource demandée.
#
# Access Token - Composition
# Chaque Token est composé de :
# Users SID : Identifier l’utilisateur auquel associé le Token
# SID of any groups the user belongs to : Permet d’identifier les droits de l’utilisateur
# Logon SID that identifies the logon session
# List of privileges the user or group has : La liste de toutes les autorisations
# Owner SID of the user who created this one : Admin local ou un admin de domaine
# SID of primary group, normally the first group they were apart of
# Default ACL when a user does not have one setup ahead of time
# Source of the access token, such as local system or a domain
# Type of Token, primary or impersonation
# Optional list of Restricted Tokens
#
# Access Token
# Type
# Il existe trois types de Token :
# Primary
# • L’Access Token standard, attribué à l’utilisateur après son authentification
# Impersonation
# • L’Access Token attribué à un utilisateur qui se connecte au nom d’un autre utilisateur. Par exemple, un
# processus qui tente d’accéder à une ressource en tant que SYSTEM.
# Restricted
# • Utiliser pour créer un Access Token à partir d’un autre afin de réduire les droits d’accès attribués. Pour le
# faire, il suffit d’invoquer l’API CreateRestrictedToken
#
# Access Token - Impersonation
# L’Impersonation est équivalent à un Runas. Ça permet à une entité (utilisateur, processus) de s’authentifier
# vis-à-vis d’une application/processus avec le compte d’une autre entité.
# Ça permet à l’entité d’accéder à une ressource en utilisant le contexte sécurité d’une autre entité ayant plus
# ou moins de privilège.
# Pour le faire, l’entité présente l’Access Token de Type Impersonation de l’entité ayant le contexte sécurité
# souhaité.
# La raison principale de l’utilisation de l’Impersonation, réside dans le besoin d’accéder à une ressource avec le
# contexte sécurité de l’utilisateur ayant fait la demande. Ainsi, le même processus peut autoriser ou non l’accès
# à une ressource tierce pour différents utilisateurs en fonction de leur Access Token.
#
#
# Access Token - Impersonation
# 1
# 2
# 3
# 4
# 1
# 2
# À l’issue de l’authentification, un Access Token est créé pour l’utilisateur. Il contient toutes les autorisations et les groupes de l’utilisateur
# Dès que l’utilisateur demande l’accès à une ressource (Secured Object) via un processus, le processus procède à la création d’un Access
# Token de type Impersonated. Ainsi, le processus va disposer de deux Tokens, son Token ainsi que le Token de l’utilisateur authentifié
# 3
# Le processus présente le Token de l’utilisateur vis-à-vis de la ressource demandée (Un fichier, un partage, une fonction, etc.)
# 4
# La ressource va procéder à une opération de contrôle d’accès via Access Liste (ACL). Cette opération consiste à comparer le SID du client
# avec les SID autorisés à accéder à la ressource
#
# Access Token – Impersonation
# Risque sécurité : Vole de l’Access Token
# Un attaquant ayant pris le contrôle d’une machine (Compte administrateur local) peut utiliser la technique
# d’Impersonation pour effectuer une élévation de privilège. Pour cela, il lui suffit de créer une copie des Access
# Token stockés au niveau de la machine et de lancer les applications de son choix via cet Access Token
# (cmd.exe, PowerShell, etc.).
# Il existe généralement deux techniques massivement utilisées par les attaquants :
# 1.Elévation vers le privilège SYSTEM au sein d’une machine
# 2.Usurpation d’identité d’un administrateur ayant des privilèges sur d’autre machine (Serveur, Contrôleur de
# domaine).
# Les Access Token sont stockés dans les machines jusqu’à son redémarrage.
#
# Access Token – Impersonation
# Risque sécurité : Vole de l’Access Token
# Elévation vers le privilège SYSTEM au sein d’une machine
# Pour se connecter en tant que SYSTEM sur une machine, l’attaquant doit identifier un processus qui tourne
# avec le compte « Local System » pour ensuite procéder à la duplication de son Access Token.
# Pour le faire, il suffit de faire appel aux API suivantes :
# -Récupérer un Handle du processus ciblé via la fonction OpenProcess avec comme paramètre l’ID du
# processus
# -Récupérer l’Access Token du processus à partir de son Handle via la fonction OpenProcesstoken avec
# comme paramètre le Handle récupéré
# -Créer une copie de l’Access Token avec la fonction DuplicateTokenEx
# À ce stade, l’attaquant dispose d’un Access Token avec les privilèges SYSTEM. Pour l’utiliser, il suffit de
# demander l’accès à une ressource en passant cet Access Token.
# Pour Exemple, l’attaquant peut lancer un Shell (cmd.exe) avec les privilèges SYSTEM en utilisant la fonction
# CreateProcessWithToken. Cette fonction prend comme paramètre l’Access Token ainsi que le processus que
# nous souhaitons lancer (cmd.exe).
# Il existe des modules sur internet qui permettent de réaliser cette attaque.
#
# Access Token – Impersonation
# Risque sécurité : Vole de l’Access Token
# Usurpation d’identité d’un administrateur ayant plus de privilèges sur le domaine
# Imaginons le cas d’un attaquant ayant réussi à prendre le contrôle d’un PC avec le compte d’un
# administrateur local sur la machine (équipe support par exemple). Ce compte ne dispose pas d’accès vers
# les serveurs, car il ne fait pas parti du groupe des administrateur Système & Réseau.
# L’attaquant va donc tenter de voler l’Access Token d’un administrateur S&R depuis la machine compromise.
# L’Access Token volé va être utilisé pour ouvrir un Shell ou le client RDP avec son niveau de privilège.
# Pour réussir son attaque, l’attaquant utilise la démarche suivante :
# -Disposer d’un Access Token du compte SYSTEM (Comme expliqué précédemment)
# -Utiliser cet Access Token pour accéder à toute les Access Token stockés dans la machine : Les Access Token
# des utilisateurs authentifiés persistent dans la machine jusqu’au reboot.
# -Identifier l’Access Token d’un administrateur S&R et le dupliquer.
# Il existe des outils qui permettent de réaliser cette attaque comme l’outil Incognito
#
#
# Access Token – Impersonation
# Risque sécurité : Vole de l’Access Token
# Utilisation d’INCOGNITO de METERPRETER
# Etape 1 : récupérer un Access Token avec des
# privilèges SYSTEM :
# Etape 3 : Lancer un Shell avec le
# compte Administrateur
# Etape 2 : Lancer INCOGNITO et lister les Token pour
# ensuite impersonate un compte Administrateur
#
# Access Token – Impersonation
# Risque sécurité : Vole de l’Access Token
# Il existe 3 méthodes pour exploiter les Token et faire l’Impersonation :
# Token Impersonation/Theft - An adversary creates a new access token that duplicates an existing token
# using DuplicateToken(Ex). The token can then be used with ImpersonateLoggedOnUser to allow the calling thread to
# impersonate a logged-on user's security context, or with SetThreadToken to assign the impersonated token to a thread. This
# is useful for when the target user has a non-network logon session on the system.
# => Ceci permet de relancer un service existant avec le nouveau Token (Dupliqué)
#
# => SetThreadToken (Id du Thread en cours d’exécution, Token dupliqué)
# Create Process with a Token - An adversary creates a new access token with DuplicateToken(Ex) and uses it
# with CreateProcessWithTokenW to create a new process running under the security context of the impersonated user. This is
# useful for creating a new process under the security context of a different user.
# => Ca permet de lancer une nouvelle application/processus avec le Token dupliquée (cmd.exe)
# Make and Impersonate Token - An adversary has a username and password, but the user is not logged onto the system. The
# adversary can then create a logon session for the user using the LogonUser function. The function will return a copy of the
# new session's access token and the adversary can use SetThreadToken to assign the token to a thread. It’s equivalent to
# runas
#
# => LogonUser Créer un Access Token d’un utilisateur à partir de son login/password
#
# => Utiliser ensuite cet access token pour lancer des process ou changer des process en cours d’exé
#
# Access Token – Impersonation
# Mesure de sécurité
# Pour rendre plus difficile l’Impersonation il faut appliquer les mesures suivantes :
# 1- Rendre plus difficile l’accès à une machine en tant que Administrateur local. C’est la mesure la plus importante : Tant que
# l’attaquant n’est pas administrateur local de la machine, il lui est impossible de dupliquer des Access Token.
# 2- Désactiver l’Impersonation des Access Token des comptes sensibles. Cette mesure doit être activée avec une grande
# précaution pour éviter tout blocage.
# “user account property page” -> “account” tab -> “account options” > Activer “Account is sensitive and cannot be used for
# delegation”
# 3- Limiter les droits des utilisateurs en enlevant le droit de création des tokens :
# GPO: Computer Configuration > [Policies] > Windows Settings > Security Settings > Local Policies > User Rights Assignment:
# Create a token object.
# Ce droit doit être utilisé uniquement en interne par le système d’exploitation (SYSTEM). À moins que cela ne soit nécessaire,
# n’affectez pas cet utilisateur directement à un utilisateur, un groupe ou un processus différent du système local. un compte
# d’utilisateur disposant de ce droit d’utilisation dispose d’un contrôle total sur le système et peut entraîner la compromission
# du système
# 4- Définir qui peut créer des Access Token pour des processus. Seul les comptes Local Service et Local Network doivent
# pouvoir le faire : Computer Configuration > [Policies] > Windows Settings > Security Settings > Local Policies > User Rights
# Assignment: Replace a process level token
#
#
# ADFS
# Active Directory Federation Server
#
# Définition
# L’ADFS est un serveur d’authentification qui permet d’implémenter un SSO via SAMLv2.
# Il peut être utilisé pour les applications internes ou externes.
# ADFS peut être hébergé en interne ou en cloud
#
# Architecture
# Interne
# DMZ
# Serveur
# d’authentification
# ADFS
# Proxy ADFS pour les
# applications
# externes
# L’annuaire des
# comptes
#
# Outil d’administration à
# distance
#
# Liste des outils
# Outil avec interface graphique
# •
# RDC > RDP > RDS – Connexion bureau à distance
# •
# RSAT / DCOM – RPC (Console.msc) –WMI en interface Graphique
# •
# AD/GPO
# •
# SCCM/Agent
# •
# GLPI, OCS Inventory/Agent
# •
# VNC
# •
# LogMeIn
# Outil en ligne de commande ou script :
# •
# PSExec
# •
# Powershell via WinRM
# •
# WMI via DCOM/RPC – WMI en ligne de commande (CMD, PS)
#
# RDC - Remote Desktop Connection
# C’est un logiciel client (mstsc.exe) pour les protocoles RDP, TSE et RDS. RDC permet de se connecter via
# interface graphique à une machine distante en utilisant un des trois protocoles :
# •
# RDP (Remote Desktop Protocol) Port 3389 : C’est juste un protocole qui permet à un utilisateur de se
# connecter sur un serveur exécutant RDS (Anciennement connu sous le nom de : Microsoft Terminal
# Service)
# •
# RDS (Remote Desktop Services) : C’est un service qui permet d’exposer le contenu d’une machine. Il
# écoute sur le port 3389 et il est accessible via le protocole RDP à partir d’un client RDC.
# •
# TSE (Terminal Server Edition) : Ancienne appellation de RDS
# •
# RemoteAPP : Permet l’accès à une seule application via RDS.
# Cette technique est probablement la plus simple et la plus appropriée à la gestion d’un serveur mais en
# redirigeant la session dans un terminal RDP, elle sera beaucoup moins adaptée à l’administration des postes
# de travail.
#
# RDC - Remote Desktop Connection
# Les rôles d’une architecture RDS sont les suivants :
# RD Web Access : le rôle Remote Desktop Services Web Access vous permet
# d’accéder aux applications installées sur un autre serveur depuis un
# navigateur Web ou depuis la fonctionnalité RemoteApp
# RemoteAPP : Permet d’afficher une application, installée sur un serveur
# distant, sur l’écran de l’utilisateur comme s’elle était installée sur ca machine.
# RD Gateway : Ce service est généralement utilisé comme une passerelle qui
# va recevoir les demandes de connexion depuis Internet et les relayer sur les
# serveurs RDS internes. Le flux RDP est encapsuler sur HTTPs (TLS)
# Le RD Connection Broker : Ce rôle va vous permettre d’équilibrer la
# charge entre les différents services publiés dans votre infrastructure. De plus,
# il va aussi gérer les reconnexions des utilisateurs pour qu’ils ne perdent pas
# leur travail, à la suite d'une coupure Internet, par exemple.
# RD Session Host : C’est le serveur ou est exposé le service RDS (port 3389)
#
# RDC - Remote Desktop Connection
# Client RDC
# Service RDS
# Protocole RDP
#
# RSAT - Outils d’administration de serveur distant
# WMI en console (interface graphique) :
# L’ensemble des outils d’administration des serveurs à distance installé sur un poste de travail d’administration.
# Ce sont des consoles qui permet à un administrateur de se connecter à certaines fonctionnalités à distance via interface
# graphique.
# Ces consoles utilisent le protocole de communication DCOM/RPC.
#
# RSAT - Outils d’administration de serveur distant
# DCOM
# API WMI (COM API)
# Le service Windows : winmgmt
# RPC
# Console.msc
#
# RSAT - Outils d’administration de serveur distant
#
# WMI en ligne de commande
# WMI est une technologie très employée dans le domaine de l’administration à distance, comme, par exemple pour interroger
# le jeu de stratégie résultant GPO, collecter des informations sur le matériel, les programmes, etc.
# Il est accessible directement en ligne de commande (via CMD ou PowerShell) ou via une console.msc.
#
# WMI en ligne de commande
# DCOM
# Commande  Get-WmiObject
# API WMI (COM API)
# Le service Windows : winmgmt
# cmd
# Commande  wmi
# RPC
#
# WinRM via PowerShell
# Cette technique est en train de généraliser. En effet, basé sur une connexion HTTP ou HTTPS (véritable lien de confiance entre
# le poste d’administration et la cible), cette fonctionnalité offre un accès à WMI via un écouteur de type Web configuré sur la
# cible.
# Utilise par défaut les ports http (5985) et HTTPS (5986)
# La console “Gestionnaire de serveur” sous Windows Server 2008 R2 est le premier outil graphique à exploiter cette technique
# de gestion
# Via PowerShell :
# PS> Enable-PSRemoting
#
# WinRM via PowerShell
# WinRM (Source)
# Script WinRM
# CMD
# PowerShe
# ll
# WinRS
# API WMI (pour machine Windows
# WinRM (Cible)
# SOAP/HTTP
#
# PSExec
# Source
# Destination
# PSExec
# PSExec
# \\Admin$
# PSExesvc
# 1- Génération de PSExesvc
# SMB (445) vers \\Admin$
# 2- Transférer le fichier vers la cible : Se connecter au
# partage \\Admin$ pour déposer l’exécutable
# PSExesvc.
# Dans le cas ou l’application a exécuter n’est pas dans
# la machine cible, elle sera déposée par PSExec dans
# le même dossier
# => Nécessite un compte admin (pwd, Hash) sur la
# destination
# PSExesvc
# PSExec
# Service Control
# Manager API
# RPC (Port 135) pour créer et lancer le service PSExesvc
# via l’API du Service Control Manager
# 3- PSExec crée et lance le service qu’il vient de déposer via l’API
# Service Control Manager : DCE/RPC  Request de l’API
# OpenSCManagerW
# - CreateServiceW Request/ SVCCTL
# - StratServiceW Request / SVCCTL
# 4- Le service est créé et lancé.
# À l’issue du lancement, des partages
# SMB sont créés et sont utilisés entre
# PSExec et PSExesvc. PSExesvc crée
# des pipes SMB pour échanger les
# commandes et les résultats. :
# \\stdin : Déposer les commandes
#
# \\Stdout : Lire les résultats de
# l’exécution
# \\stderr : Pour les erreurs
# \\stdin
# \\stdout
# \\stderr
# SMB
# SMB (445) vers \\stdin
# SMB (445) vers \\stdout
# SMB (445) vers \\stderr
# 5- communication avec PSExesvc via les pipes
# SMB créés
# À la fin de l’exécution, PSExec désinstalle le service PSExesvc et supprimer les fichiers
#
# VNC
# Architecture client-serveur.
# On installe un serveur sur un poste ou un serveur et un client sur un pc d’administration. Le client permet
# d’accéder au serveur. C’est comme un TeamViewer, la session actuellement connectée sur la machine n’est
# pas impacté, contrairement à RDP qui ouvre une nouvelle session.
# Ceci est très utile lorsqu’un administrateur souhaite dépanner un pc de supervision par exemple (PCPASS). On
# se connecte, on effectue les modifications, et on se déconnecte. Le PC n’a donc même pas besoin d’avoir un
# clavier/souri.
# Il peut être implémenté via ultraVNC. L’authentification peut être intégrée à l’AD. On définit des groupes
# d’utilisateur ayant le droit de se connecter à une machine via ultraVNC
#
# Compte de service
#
# Services
# Service
# Un service est un processus qui tourne en arrière-plan sans forcément une action de lancement
# par l’utilisateur. Il peut être lancé dès le démarrage du poste de travail ou du serveur pour réaliser
# certaines fonctions système (réseau, noyau, etc.)
# Vu que le service se lance sans action utilisateur, il ne prend pas le contexte de l’utilisateur pour
# s’exécuter et réaliser des actions sur la machine (lecture/écriture). Donc il a besoin d’un compte
# utilisateur dédié (qu’on appelle un compte de service) pour se lancer tout seul.
# Donc un service a besoin d’un compte de service  pour se lancer sur la machine.
# Exemple de service :
# -
# Des services windows
# o
# Wireless service
# o
# Gestionnaire des comptes
# o
# Audio service
# o
# Gestionnaire des connexions à distance
# o
# Etc.
# -
# Des services qu’on installe
# o
# SQL Service
# o
# Antivirus
#
# Comptes de Services
# Les comptes de services
# C’est ce qui permet à un service de s’exécuter à l’arrière-plan.
# Il possède des privilèges qu’il attribue au service lancé.
# On peut créer des comptes de service et les utilisés en fonction du besoin (moindre privilège)
# Windows possède des comptes de services par défaut (compte de service virtuel) :
# -
# Système local : Le compte de service avec le max de privilège (plus que l’administrateur, mais
# l’administrateur peut s’attribuer les droits qu’il veut).
#  Il ne faut pas l’utiliser pour tous les services. L’antivirus est généralement lancé avec ce compte
# -
# Service local : Un compte de service avec des privilèges équivalents à ceux d’un compte
# utilisateur normale.
# On peut l’utiliser pour les services qui n’ont pas besoin de droit d’administration. Par contre si on
# l’utilise pour tous les services, un attaquant qui arrive à compromettre se compte aura la
# possibilité de lancer l’ensemble des services. Même s’il ne dispose pas des droits d’admin.
# -
# Service réseau : Il a les mêmes droits que le compte service local mais avec des privilèges réseau
# (accès aux sockets, etc.).
#
# Application et logiciel
# Application/logiciel :
# C’est un exécutable qui s’Install par un administrateur et qui se lance par
# un utilisateur (contrairement à un service qui se lance en arrière-plan).
# ...
# téléphone avec l’autocome.
#
# Trunk SIP
# Autocom CCI
# Réseau
# Switch, routeur, etc
# Téléphone
# IP
# Téléphone
# IP
# Téléphone
# IP
# Téléphone
# IP
# • Le Trunk SIP est utilisé pour
# permettre à deux sociétés de
# faire des appels via leur
# Autocom au lieu de passer par
# les opérateurs téléphoniques
# • Ceci se fait via la configuration
# d’un canal de communication
# réseau entre les deux
# Autocoms.
# • Dans le schéma, les téléphones
# de la CCI peuvent appeler les
# téléphones de PAE,
# gratuitement sans passer par
# l’OPT. Pour cela, des numéros
# internes sont utilisés
# Autocom PAE
# IP
#
# Virtual Desktop
#
# VMWare Horizon
# Une solution de virtualisation des postes de travail
# Les sessions sont stockées sur des serveurs et sont accessibles par des clients (application mobile,
# application sur pc ou navigateur en html5)
# Tout le stockage est centralisé, les salariés n’ont plus besoin d’avoir un pc dédié et peuvent accéder à leur
# session partout dans le monde, même depuis un téléphone portable.
# Sécurité :
# • Authentification forte
# • Sauvegarde des serveurs
# • MCS
#
#
# Virtualisation via VMWare
#
# Généralité
#
# Deux Serveurs ESX avec chacun un SAN avec plusieurs disque dure
#
#
#
#
#
#
#
# Architecture
# Serveur physique
# Hyperviseur
# Ex : ESXi
# Machine Virtuelle
#
# Composants de la suite vSphere
# ESXi
# L’hyperviseur (le serveur qui gère
# les VM)
# Il a son propre OS (Appliance
# VMWare)
# vCenter Server
# Serveur d’administration
# centralisé des ESX et de
# leurs VM.
# C’est plus puissant qu’un
# simple client vSphere
# vSphere
# Client
# Administrer
# directement un
# ESXi
# Administrer
# plusieurs ESXi via
# le serveur vCenter
# vMotion, VMware High Availability, VMware
# Update Manager and VMware Distributed
# Resource Scheduler (DRS).
# Accès en HTTPs
#
# Composants de la suite vSphere
#
#
#
#
#
# Réseau
#
# Réseau
# •
# Chaque ESX possède par 4 interface :
# •
# VLAN Management : Administration de l’ESX via
# vSphere
# •
# VLAN VMotion : Automatiser la migration des VMs
# entre plusieurs serveurs physiques
# •
# VLAN vSAN : Gérer le stockage dans le vSAN
# •
# VLANs pour les VM hébergées dans l’ESXi
# •
# On déclare dans l’ESX les VLANs qui peuvent être
# attribués à ses VM
# •
# On attribut une ou plusieurs VM aux VLANs déclarés
# •
# Ici par exemple :
# •
# Dans le VLAN CCI-TTA-RESA-SRV-INFRA
# •
# Il y a 3 VMs
#
# SI d’administration
# ESX
# VM
# VM
# VLA
# N
# Res.
# Adm
# in
# VLA
# N
# Exp
# vSphere
# VLA
# N
# Outil
# Adm
# in
# Vlan des ressources
# administrées
# Vlan des outils
# d’administrati
# on
# VLAN d’exploitation
# Production
# •
# Chaque VM doit avoir deux pates
# réseaux virtuelles : Une de production
# et une d’admin
# •
# La Pate de management de l’ESX doit
# être également dans le VLAN
# d’administration
#
# Journalisation des ESXi via LogInsight
# Stockage et visualisation des logs des ESXi
# ESX
# VM
# VM
# ESX
# VM
# VM
# LogInsight
#
# Connexion directe à un ESX via KVM
#
# Les modules
# HA : Module de haute disponibilité
# Il permet de redémarrer les VM sur un autre site s’il voit que le site concerné ne répond pas.
# Il s’assure qu’il y a assez de ressource sur chaque ESXi, sinon il réparti les charges entre les ESXi
# DRS : Répartition des charges entre les ESXi
# Si on passe un ESXi en mode maintenance, le DRS permet de basculer automatiquement les VM de l’ESXi vers
# le reste des ESXi
# C’est deux modules DRS et HA sont inclus dans la licence Entreprise +
#
# Witness
#
# Présentation
# Le Witness est une VM qui sert à vérifie que les ESX sont up and running.
# Pour une utilisation efficace, il faut respecter un certain nombre de mesures de sécurité :
# • Le witness ne doit pas être dans les serveurs ESX qui contrôle. Il doit être soit dans les ESX d’un autre site
# qui ne contrôle pas, soit dans un serveur physique dédié, soit dans un poste de travail (client léger)
# • Le witness ne doit pas être dans les mêmes locaux techniques qui hébergent les ESX, car en cas
# d’incident physique (feux, coupure d’élec, etc.) on perd également le witenss
# • Le Witness ne doit pas être dans un site distant qui traverse des réseaux internet ou opérateur non
# redondé. Car on cas de perte de connexion, les ESX seront invisible pour le witness.
# • Les seuls cas ou le witness peut être dans un site distant c’est quand on dispose d’un lien MPLS
# redondé avec une garanti de l’opérateur sur la disponibilité du lien.
# • Le witness doit avoir un lien physique avec la première salle ou il y a les ESX et un deuxième lien physique
# avec la deuxième salle.
#
# Schéma
#
# VPN
# Accès nomade et accès site à site
#
# Nomadisme via Direct Access
# Passerelle VPN
# Particularité de Direct Access :
# - Connexion automatique : Transparent pour l’utilisateur, aucune client VPN à lancer
#
# Nomadisme via Direct Access
# DMZ
# L’accès à internet doit se faire depuis le VPN pour permettre de contrôler le trafic
# Pare-feu interne là où on
# met les règles de filtrage
# (DA vers serveurs
# internes)
#
# Nomadisme via Direct Access
# Direct Access est un service gratuitement offert sur les serveurs Windows pour les
# licences Enterprise (Serveur et poste de travail)
#
# VPN site à site
# Permet de protéger les flux qui transitent dans un réseau non maitrisé comme internet ou le réseau
# d’opérateur (liaison spéciale)
# Le tunnel VPN est monté entre les pare-feu internes (Un pare-feu comme passerelle VPN et l’autre comme
# client VPN)
# Une fois le tunnel VPN configuré entre les deux pares-feux, il faut choisir les VLANs source et destination qui
# ont le droit de circulé à l’intérieur du VPN.
# Si il y a un besoin de faire circuler les flux dans les deux sens entre les deux sites, il est préférable de monter
# deux tunnel VPN.
# Pare-feu externe
# Pare-feu interne
# VPN/IPSec
#
# VPN Multisite- VPN IPsec multipoint dynamique DMVPN – Solution de
# CISCO
# • Permet d’Interconnecter plusieurs sites à un site principal, et peut-être également entre eux, à travers Internet tout
# en cryptant le trafic pour le protéger.
# • Réseau Point à point avec une architecture en étoile.
# • Chaque site se connecte au routeur du site principale
# • On définit deux sites principaux pour avoir une redondance d’accès. Si un lien tombe l’autre prend le relais
#
# VPN Multisite- VPN IPsec multipoint dynamique DMVPN – Solution de
# CISCO
#
# Volume Shadow-Copy Service
# Outil de sauvegarde des fichiers/répertoires
# Cliché instantané des volumes
#
# Sommaire
# •
# Présentation
# •
# Architecture
# •
# Installation
# •
# Utilisation
# Résumé :
# Volume Shadow Copy (appelé aussi Volume Snapshot Service ou VSS ou Cliché
# instantané des volumes), est une technologie intégrée à Microsoft Windows. Il vous
# permet de créer des sauvegardes de fichiers ou de disques manuellement ou
# automatiquement, même s'ils sont en cours d'utilisation.
# Les sauvegardes sont stockées dans les disques dures. Donc ça permet de récupérer
# un fichier supprimé/modifié par erreur plutôt que de devoir remettre la bande de
# sauvegarde.
#
# Présentation
# VSS est un service de sauvegarde intégré dans Microsoft et permet de faire des snapshot sur les répertoires et les disques
# d’une machine.
# Concrètement, si le service est activé et configuré pour sauvegarder périodiquement une version du disque D:\\, alors
# l’utilisateur peut remonter aux versions antérieures de ces documents stockés dans le D:\\
# L’avantage de ce service c’est qu’il permet de capturer des copies instantanées de fichiers en cours d'exécution ou de
# l'intégralité d'un disque dur à un moment donné.
# C’est notamment une bonne solution à utiliser face au risque de chiffrement de vos fichiers par cryptolockers. Même s’elle
# n’est pas efficace car l’attaquant va commencer par désactiver le service VSS et supprimer les données sauvegardées.
#
# Architecture
# Fonctionnement :
# Shadow Copy fonctionne schématiquement de la façon suivante, en trois étapes:
# 1.
# Fige les entrées/sorties : pendant un instant, les fichiers ou le disque sont positionnés en lecture seule
# pour empêcher de nouvelles écritures
# 2.
# Prise d'image : copie des blocs nécessaire à la reconstitution ultérieure
# 3.
# Déverrouille le disque ou les fichiers pour permettre de nouvelles mises à jour
# Pour permettre ce fonctionnement, le service VSS doit communiquer avec l’application qui écrit les données
# pour lui demander d’arrêter toute modification pendant le snapshot.
# Le service VSS informe ensuite la solution de sauvegarde de commencer le snapshot. Une fois terminée, le VSS
# informe l’application qu’elle peut reprendre les opérations d’écriture.
# Le module de l’application qui communique avec le service VSS est le VSS writer
# Le module de sauvegarde est VSS requestor
#
# Architecture
# L’architecture du service VSS s’appuie sur trois composants principaux :
# • Le requêteur VSS – Initie la sauvegarde : ce composant est en général embarqué dans
# l’agent de sauvegarde fourni par l’application de sauvegarde qui initie le processus de
# backup.
# • Le « VSS Writer » - Dans l’application : ce composant de VSS est généralement délivré par les
# applications (typiquement SQL Server, Exchange, le file system Windows…). Sa mission est
# d'assurer la consistance des données afin que l’état de l’application permette une
# sauvegarde fidèle de l’application.
# • Le VSS Provider – Dans l’espace de stockage : ce dernier élément est fourni par la couche de
# stockage (qu’il s’agisse d’un logiciel de stockage ou d’une baie de stockage). Sa mission est
# de mettre à disposition de l’application de sauvegarde un instantané des données de
# l’application à protéger.
# • Le  service VSS de Windows
#
# Architecture
# Fonctionnement :
# 1. Le requêteur VSS de l’agent de sauvegarde demande à VSS la liste des workloads susceptibles d'être
# sauvegardées.
# 2. VSS énumère toutes les applications qui ont enregistré un « VSS Writer ».
# 3. Le requêteur VSS de l'agent de sauvegarde demande que la charge de travail soit préparée pour la
# sauvegarde.
# 4. Le composant VSS Writer de l’application à sauvegarder effectue les opérations nécessaires pour que
# l’application soit prête à la sauvegarde (mise en cohérence des données, vidage des données en cache…).
# 5. Après cette préparation des données, le VSS writer de l’application notifie le service VSS et le « VSS Provider »
# que l’application est dans un état qui rend possible la sauvegarde.
# 6. Le VSS Provider prend un cliché instantané des données (snapshot) et en informe le requêteur VSS.
# 7. Le requêteur VSS enregistre le snapshot dans le VSS Provider et envoie les données vers le serveur de
# sauvegarde.
# 8. Une fois la sauvegarde achevée, le service VSS notifie le VSS provider qu’il peut libérer l’espace occupé par
# le snapshot et informe le VSS Provider que les données sont sauvegardées. L’application peut alors réaliser ses
# tâches de maintenance post-sauvegarde.
#
# Installation
# Il faut tout d’abord démarrer le service VSS :
# Une fois activer, il faut configuration une tache planifier pour effectuer les sauvegardes d’un espace de stockage :
# https://www.ubackup.com/fr/windows-10/activer-cliche-instantane-des-volumes.html
# https://www.ubackup.com/fr/windows-10/activer-
# cliche-instantane-des-volumes.html
#
# Utilisation
# Une fois le service est activé et configuré, les fichiers seront sauvegardés avec la
# politique que nous avons défini (Période, etc.)
# Si nous avons supprimé un fichier par erreur, il suffit de faire un clic droit sur le C:\\,
# restaurer les versions précédentes.
#
# Historique de fichier
# Le VSS propose ainsi une fonction similaire au service « Historique de Fichier ».
# L’Historique des fichiers de Windows enregistre les différentes versions de vos fichiers et vous
# permet de revenir à une version intermédiaire si vous n’êtes pas satisfait de la dernière version en
# date.
# Pour l’utiliser il suffit de :
# - Activer la fonction Historique des
# fichiers
# - Choisir un emplacement pour
# stocker l’historique (Partition dédié,
# Disque interne, disque externe ou
# emplacement réseau)
# - Configurer ensuite la politique de
# sauvegarde (Fréquence, fichier
# sauvegardé, rétention)
#
# WEBMin
# Outil d’administration des serveurs Linux via HTTP
#
# Présentation de l’outil
# Webmin est une interface web qui permet d'administrer simplement un serveur UNIX ou
# Linux à distance via n'importe quel navigateur web.
# URL : https://www.mondomaine.com:10000
#
#
# User question:  What is an HSM ?
# additional information :  {'file': 'content', './uploads/lettre-de-procuration-dadie_2.pdf': "                                                                                              \n \n \n \n \n \n \n \n \n \n Fait à Anières-Sur-Seine, Le 17/06/2025 \nJe soussigné M. DADIE Koutoua Christ né(e) le 09/07/2001 donne par la présente procuration à M. Emmanuel \nKONAN pour la réalisation des tâches suivantes en mon nom pour le logement N°116 de la résidence les Aiglons \nsituée au 145 Bd. National 92500, Rueil Malmaison. \n☒  Réalisation et signature de l'état des lieux (entrée et sortie) \n☒  Signature de mon contrat de location \nCette procuration est valable du 17/06/2025 au 18/06/2025. \nPour faire valoir ce que de droit. \nBon pour mandat                                                                 Bon pour acceptation \nSignature :                                                         Signature du bénéficiaire de la procuration :  \nPensez à présenter la carte d'identité du mandant et du mandataire  \n \n  \n", './uploads/150ce100-f227-42ed-bd08-f3d69e87234c.pdf': 'Ornisec Academy\nConnaissances Systèmes et réseaux\n\nIntroduction\n\nIntroduction\nCette formation consiste à introduire les notions techniques de\nbase\npermettant\nà\nun\nconsultant/auditeur\nde\nmieux\ncomprendre les mesures de sécurité appliquées dans les\ndifférents types d’environnement.\nElle couvre à la fois les périmètres Système et Réseau.\n\nProcessus d’une entreprise\n\nProcessus d’une entreprise\nAfin de mieux comprendre les différents risques métiers d’une entreprise, il faut tout d’abord comprendre le \nfonctionnement général d’une entreprise, à savoir les processus et leur organisation. \nCe chapitre permet de présenter les processus classiques d’une organisation ainsi que le rôle de chaque \nprocessus. On les retrouve notamment lors des analyses des risques (valeur métier => Mission)\nChaque entreprise, réalise des missions. Une mission est pilotée par un service/département et consiste à réaliser \nun certain nombre de processus (activité périodique ayant des inputs et produisant des outputs) \n\nTraitement, \nTransformation, \nValeur ajoutée\nProcessus\nInput\nOutput\nL’approche par les processus permet d’améliorer l’efficacité \nde l’organisation.\nLe management par les processus est un levier de la \nperformance de l’organisation \nCadrer par le norme ISO 9000 (Processus \nQualité)\nApproche par processus\n\nTypes de processus en entreprise\nPour peu classer les métiers d’une entreprise en 3 catégories de processus :\n•\nProcessus de management : L’ensemble des activités pilotées par la DG afin de gérer et piloter la société \n✓Définition des stratégies pluriannuelles \n✓Programme de transformation \n✓Programme de croissance (fusion & acquisition) \n✓Gestion de la performance de l’activité \n✓…..\n•\nProcessus opérationnel (Production) : Ce sont les activités de base d’une entreprise, le cœur de métier et les \nmissions principales (raisons d’être d’une entreprise)\n✓R&D\n✓Fabrication de produit \n✓Transport de passager \n✓Inspection et filtrage de marchandise\n✓…..\n•\nProcessus support : Tout ce qui permet la réalisation des processus opérationnels \n✓Gestion RH\n✓Gestion financière \n✓IT \n✓….\n\nMANAGEMENT\nPROCESSES\nOPERATING \nPROCESSES\nSUPPORT\nPROCESSES\nOFFERS, SOLUTIONS & TECHNOLOGIES MANAGEMENT\nGLOBAL ENGINEERING & DELIVERY MANAGEMENT\nOPERATIONS & CAPACITY MANAGEMENT\nR&D\nFINANCE\nPURCHASING\nSales\nHR\nIT\nLEGAL\nINTERNAL AUDIT,\nRISKS &\nINTERNAL\nCONTROL\nMANAGEMENT\nKM\nSTRATEGY\n& MARKETING\nGENERAL \nMANAGEMENT\nTRANSFORMATION\nCOMMUNICATION\nTypes de processus en entreprise\nCi-dessous un exemple de processus de la société ALTRAN, cabinet de conseil en IT \n\nMANAGEMENT\nPROCESSES\nOPERATING\nPROCESSES\nSUPPORT\nPROCESSES\nProcessus de Direction\nIls sont placés sous la responsabilité du dirigeant qui fixe les objectifs et déploie les ressources \nnécessaires. (Stratégie Global, analyse des résultats, amélior ...
